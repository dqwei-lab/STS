# %%
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../..")
from chemocommons import *
# Out:
# D:\Anaconda3\envs\py36\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
def load_print(name):
    models = load(name + ".joblib")[0]
    model_pd = pd.DataFrame(models.cv_results_)
    print(models.best_score_)
    print(models.best_params_)
    display(model_pd.filter(like="mean_test"))

# %%
load_print("rakeld-lgb")
# Out:
# 0.6679306608884074
# {'labelset_size': 8}
#    mean_test_hamming loss  mean_test_aiming  mean_test_coverage  \
# 0               -0.051171          0.731166            0.711425
# 1               -0.050796          0.738344            0.714649
# 2               -0.051129          0.743843            0.720439
# 3               -0.051504          0.742994            0.720018
# 4               -0.051463          0.749233            0.726592
# 5               -0.052004          0.745693            0.718067
# 6               -0.051254          0.758893            0.728705
# 7               -0.051963          0.756681            0.730930
# 8               -0.053379          0.750614            0.721802
#
#    mean_test_accuracy  mean_test_absolute true
# 0            0.689002                 0.636511
# 1            0.695269                 0.644637
# 2            0.700062                 0.648971
# 3            0.700342                 0.650596
# ...

# %%
load_print("lgb")
# Out:
# 0.6787648970747562
# {'classifier': LabelPowerset(classifier=LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                         colsample_bytree=1.0,
#                                         importance_type='split',
#                                         learning_rate=0.1, max_depth=-1,
#                                         min_child_samples=20,
#                                         min_child_weight=0.001,
#                                         min_split_gain=0.0, n_estimators=60,
#                                         n_jobs=-1, num_leaves=31,
#                                         objective=None, random_state=None,
#                                         reg_alpha=0.0, reg_lambda=0.0,
#                                         silent=True, subsample=1.0,
#                                         subsample_for_bin=200000,
#                                         subsample_freq=0),
# ...

# %%
load_print("xgb")
# Out:
# 0.685807150595883
# {'classifier': LabelPowerset(classifier=XGBClassifier(base_score=0.5, booster='gbtree',
#                                        colsample_bylevel=1, colsample_bytree=1,
#                                        gamma=0, learning_rate=0.1,
#                                        max_delta_step=0, max_depth=3,
#                                        min_child_weight=1, missing=nan,
#                                        n_estimators=100, n_jobs=1, nthread=None,
#                                        objective='binary:logistic',
#                                        random_state=0, reg_alpha=0,
#                                        reg_lambda=1, scale_pos_weight=1,
#                                        seed=None, silent=True, subsample=1),
#               require_dense=[True, True]), 'classifier__classifier': XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
# ...

# %%
load_print("rf")
# Out:
# 0.6917659804983749
#    mean_test_hamming loss  mean_test_aiming  mean_test_coverage  \
# 0               -0.051963          0.768608            0.731859
# 1               -0.052671          0.771091            0.735291
# 2               -0.052004          0.769384            0.734004
# 3               -0.052296          0.772409            0.734980
# 4               -0.050629          0.776445            0.739769
# 5               -0.052504          0.772797            0.736632
# 6               -0.051046          0.772183            0.737042
# 7               -0.052588          0.769809            0.733978
#
#    mean_test_accuracy  mean_test_absolute true
# 0            0.722731                 0.683099
# 1            0.724402                 0.684724
# 2            0.724840                 0.685265
# 3            0.724299                 0.682015
# 4            0.731047                 0.691766
# 5            0.726256                 0.685807
# ...

# %%
load_print("ext")
# Out:
# 0.6820151679306609
#    mean_test_hamming loss  mean_test_aiming  mean_test_coverage  \
# 0               -0.053171          0.761168            0.730875
# 1               -0.054046          0.763624            0.732578
# 2               -0.052129          0.766423            0.733292
# 3               -0.052796          0.768797            0.737566
# 4               -0.052963          0.762721            0.731272
# 5               -0.053588          0.764103            0.733494
# 6               -0.052296          0.766197            0.734312
# 7               -0.053004          0.769971            0.738212
#
#    mean_test_accuracy  mean_test_absolute true
# 0            0.718863                 0.679848
# 1            0.719095                 0.677140
# 2            0.721833                 0.679307
# 3            0.724200                 0.681473
# 4            0.719931                 0.679307
# 5            0.719947                 0.677140
# ...

# %%
load_print("mtsvm")
# Out:
# 0.27627302275189597
#    mean_test_hamming loss  mean_test_aiming  mean_test_coverage  \
# 0               -0.192266          0.403452            0.880906
# 1               -0.113676          0.456220            0.712893
# 2               -0.089591          0.416683            0.540008
# 3               -0.085174          0.310618            0.356415
# 4               -0.082757          0.281455            0.296060
# 5               -0.083840          0.249558            0.259314
# 6               -0.086341          0.225153            0.235614
# 7               -0.088007          0.214247            0.228927
# 8               -0.089049          0.230462            0.261571
# 9               -0.089174          0.228774            0.261796
#
#    mean_test_accuracy  mean_test_absolute true
# 0            0.391886                 0.159263
# 1            0.437593                 0.244312
# 2            0.398033                 0.276273
# 3            0.294579                 0.229686
# ...

# %%
load_print("rakeld-nb")
# Out:
# 0.34615384615384615
#    mean_test_hamming loss  mean_test_aiming  mean_test_coverage  \
# 0               -0.136345          0.485662            0.737899
# 1               -0.131344          0.489424            0.736121
# 2               -0.126677          0.493743            0.729229
# 3               -0.125177          0.498480            0.727127
# 4               -0.119635          0.507124            0.711405
# 5               -0.117051          0.515903            0.701708
# 6               -0.113676          0.528539            0.704826
# 7               -0.112176          0.516847            0.687968
# 8               -0.108051          0.524865            0.675675
#
#    mean_test_accuracy  mean_test_absolute true
# 0            0.468970                 0.262730
# 1            0.473084                 0.269231
# 2            0.476266                 0.277356
# 3            0.482583                 0.293066
# 4            0.487808                 0.308234
# ...

# %%
load_print("rakeld-rf")
# Out:
# 0.6457204767063922
#    mean_test_hamming loss  mean_test_aiming  mean_test_coverage  \
# 0               -0.054255          0.686981            0.669008
# 1               -0.053754          0.697039            0.676634
# 2               -0.054171          0.707268            0.686119
# 3               -0.054421          0.701869            0.684243
# 4               -0.054588          0.719610            0.699175
# 5               -0.054838          0.730544            0.707185
# 6               -0.053838          0.730968            0.706819
# 7               -0.055588          0.727492            0.707426
# 8               -0.055838          0.730923            0.703821
#
#    mean_test_accuracy  mean_test_absolute true
# 0            0.649263                 0.603467
# 1            0.658061                 0.612134
# 2            0.667088                 0.619177
# 3            0.665798                 0.622969
# 4            0.682093                 0.638678
# ...

# %%
print(rf.best_estimator_.clusterer.method)
print(ext.best_estimator_.clusterer.method)
# Out:
# louvain
# lpa

# %%
mlknn = load("mlknn.joblib")
mlknn_pd = pd.DataFrame(mlknn.cv_results_)
mlknn_pd.filter(like="mean_test")
# Out:
#    mean_test_hamming loss  mean_test_aiming  mean_test_coverage  \
# 0               -0.061672          0.731354            0.721935
# 1               -0.070089          0.685268            0.707798
# 2               -0.057005          0.719258            0.707640
# 3               -0.057713          0.679388            0.661604
# 4               -0.056796          0.710139            0.689836
# 5               -0.056671          0.703070            0.688213
# 6               -0.058130          0.694926            0.678766
# 7               -0.055588          0.703927            0.677259
# 8               -0.057630          0.692127            0.672466
# 9               -0.057796          0.674251            0.649890
#
#    mean_test_accuracy  mean_test_absolute true
# 0            0.690114                 0.631636
# 1            0.653296                 0.585590
# 2            0.678193                 0.619718
# 3            0.641201                 0.593716
# ...

# %%
mlknn.

# %%
rakeld = load("rakeld.joblib")[0]
rakeld_pd = pd.DataFrame(rakeld.cv_results_)
rakeld_pd.filter(like="mean_test")
# Out:
#    mean_test_hamming loss  mean_test_aiming  mean_test_coverage  \
# 0               -0.136345          0.485662            0.737899
# 1               -0.131344          0.489424            0.736121
# 2               -0.126677          0.493743            0.729229
# 3               -0.125177          0.498480            0.727127
# 4               -0.119635          0.507124            0.711405
# 5               -0.117051          0.515903            0.701708
# 6               -0.113676          0.528539            0.704826
# 7               -0.112176          0.516847            0.687968
# 8               -0.108051          0.524865            0.675675
#
#    mean_test_accuracy  mean_test_absolute true
# 0            0.468970                 0.262730
# 1            0.473084                 0.269231
# 2            0.476266                 0.277356
# 3            0.482583                 0.293066
# 4            0.487808                 0.308234
# ...
